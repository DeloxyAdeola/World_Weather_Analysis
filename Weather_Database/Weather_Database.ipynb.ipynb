# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 767

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ### Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jian
# Processing Record 2 of Set 1 | salima
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | jizan
# Processing Record 6 of Set 1 | longyearbyen
# Processing Record 7 of Set 1 | pandan
# Processing Record 8 of Set 1 | riberalta
# Processing Record 9 of Set 1 | tuktoyaktuk
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | safaga
# Processing Record 12 of Set 1 | poya
# Processing Record 13 of Set 1 | angoche
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | adrar
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | halifax
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | young
# Processing Record 23 of Set 1 | mundo nuevo
# Processing Record 24 of Set 1 | ilo
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | albany
# Processing Record 27 of Set 1 | vostok
# Processing Record 28 of Set 1 | port lincoln
# Processing Record 29 of Set 1 | coos bay
# Processing Record 30 of Set 1 | provideniya
# Processing Record 31 of Set 1 | abu dhabi
# Processing Record 32 of Set 1 | dauphin
# Processing Record 33 of Set 1 | robore
# Processing Record 34 of Set 1 | mataura
# Processing Record 35 of Set 1 | rundu
# Processing Record 36 of Set 1 | rovenki
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | ukiah
# Processing Record 40 of Set 1 | krasnogorskoye
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | husavik
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | amot
# Processing Record 47 of Set 1 | pisco
# Processing Record 48 of Set 1 | clyde river
# Processing Record 49 of Set 1 | bluff
# Processing Record 50 of Set 1 | chuy
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | barrow
# Processing Record 3 of Set 2 | narsaq
# Processing Record 4 of Set 2 | lawrence
# Processing Record 5 of Set 2 | constitucion
# Processing Record 6 of Set 2 | zakharovo
# Processing Record 7 of Set 2 | callaguip
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | mabaruma
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | dawei
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | cherskiy
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | atuona
# Processing Record 16 of Set 2 | bara
# Processing Record 17 of Set 2 | adolfo lopez mateos
# Processing Record 18 of Set 2 | hithadhoo
# Processing Record 19 of Set 2 | ponta do sol
# Processing Record 20 of Set 2 | saldanha
# Processing Record 21 of Set 2 | castro
# Processing Record 22 of Set 2 | duz
# City not found. Skipping...
# Processing Record 23 of Set 2 | mana
# Processing Record 24 of Set 2 | tocopilla
# Processing Record 25 of Set 2 | mareeba
# Processing Record 26 of Set 2 | romny
# Processing Record 27 of Set 2 | camacha
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | margate
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | paita
# Processing Record 32 of Set 2 | alpena
# Processing Record 33 of Set 2 | westport
# Processing Record 34 of Set 2 | bengkulu
# Processing Record 35 of Set 2 | ordynskoye
# Processing Record 36 of Set 2 | bethel
# Processing Record 37 of Set 2 | mount gambier
# Processing Record 38 of Set 2 | carnarvon
# Processing Record 39 of Set 2 | vargashi
# Processing Record 40 of Set 2 | busselton
# Processing Record 41 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 42 of Set 2 | shiraz
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | grindavik
# Processing Record 45 of Set 2 | luderitz
# Processing Record 46 of Set 2 | faya
# Processing Record 47 of Set 2 | meulaboh
# Processing Record 48 of Set 2 | vuktyl
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | cayenne
# Processing Record 1 of Set 3 | khani
# Processing Record 2 of Set 3 | yershichi
# Processing Record 3 of Set 3 | srednekolymsk
# Processing Record 4 of Set 3 | auki
# Processing Record 5 of Set 3 | algiers
# Processing Record 6 of Set 3 | ayan
# Processing Record 7 of Set 3 | tiksi
# Processing Record 8 of Set 3 | labytnangi
# Processing Record 9 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 3 | padang
# Processing Record 11 of Set 3 | labuhan
# Processing Record 12 of Set 3 | butaritari
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | yar-sale
# Processing Record 17 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 3 | richards bay
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | nushki
# Processing Record 21 of Set 3 | bilibino
# Processing Record 22 of Set 3 | palauig
# Processing Record 23 of Set 3 | avera
# Processing Record 24 of Set 3 | bathsheba
# Processing Record 25 of Set 3 | new norfolk
# Processing Record 26 of Set 3 | pendleton
# Processing Record 27 of Set 3 | jumla
# Processing Record 28 of Set 3 | tilichiki
# Processing Record 29 of Set 3 | manadhoo
# Processing Record 30 of Set 3 | khatanga
# Processing Record 31 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 3 | mikhaylovka
# Processing Record 33 of Set 3 | codrington
# Processing Record 34 of Set 3 | hanzhong
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | limoux
# Processing Record 37 of Set 3 | ribeira grande
# Processing Record 38 of Set 3 | nassau
# Processing Record 39 of Set 3 | gat
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | inhambane
# Processing Record 42 of Set 3 | trelew
# Processing Record 43 of Set 3 | klaksvik
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | nanortalik
# Processing Record 46 of Set 3 | kudahuvadhoo
# Processing Record 47 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 3 | hilo
# Processing Record 49 of Set 3 | kavaratti
# Processing Record 50 of Set 3 | estreito
# Processing Record 1 of Set 4 | puerto ayora
# Processing Record 2 of Set 4 | taltal
# Processing Record 3 of Set 4 | praia da vitoria
# Processing Record 4 of Set 4 | el dorado
# Processing Record 5 of Set 4 | brae
# Processing Record 6 of Set 4 | zhitikara
# City not found. Skipping...
# Processing Record 7 of Set 4 | saumur
# Processing Record 8 of Set 4 | avarua
# Processing Record 9 of Set 4 | karratha
# Processing Record 10 of Set 4 | seguin
# Processing Record 11 of Set 4 | kendari
# Processing Record 12 of Set 4 | sinnamary
# Processing Record 13 of Set 4 | durango
# Processing Record 14 of Set 4 | tymovskoye
# Processing Record 15 of Set 4 | antigonish
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | jamestown
# Processing Record 18 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 4 | xuddur
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | lagoa
# Processing Record 22 of Set 4 | gasa
# Processing Record 23 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 24 of Set 4 | pevek
# Processing Record 25 of Set 4 | portland
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | bredasdorp
# Processing Record 28 of Set 4 | aykhal
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | rio grande
# Processing Record 31 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 4 | mayumba
# Processing Record 33 of Set 4 | berlin
# Processing Record 34 of Set 4 | poum
# Processing Record 35 of Set 4 | shenjiamen
# Processing Record 36 of Set 4 | pontes e lacerda
# Processing Record 37 of Set 4 | dhidhdhoo
# Processing Record 38 of Set 4 | astoria
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | panama city
# Processing Record 41 of Set 4 | kurchum
# Processing Record 42 of Set 4 | chifeng
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | verkhnyaya tura
# Processing Record 45 of Set 4 | pierre
# Processing Record 46 of Set 4 | georgetown
# Processing Record 47 of Set 4 | ternate
# Processing Record 48 of Set 4 | palana
# Processing Record 49 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 4 | buala
# Processing Record 1 of Set 5 | yekaterinoslavka
# Processing Record 2 of Set 5 | sur
# Processing Record 3 of Set 5 | norman wells
# Processing Record 4 of Set 5 | saint-georges
# Processing Record 5 of Set 5 | kahama
# Processing Record 6 of Set 5 | alugan
# Processing Record 7 of Set 5 | colares
# Processing Record 8 of Set 5 | itarema
# Processing Record 9 of Set 5 | nuuk
# Processing Record 10 of Set 5 | zhanakorgan
# Processing Record 11 of Set 5 | taoudenni
# Processing Record 12 of Set 5 | kruisfontein
# Processing Record 13 of Set 5 | bubaque
# Processing Record 14 of Set 5 | karakol
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | andenes
# Processing Record 17 of Set 5 | pouebo
# Processing Record 18 of Set 5 | berlevag
# Processing Record 19 of Set 5 | tasiilaq
# Processing Record 20 of Set 5 | bambous virieux
# Processing Record 21 of Set 5 | tuatapere
# Processing Record 22 of Set 5 | laguna
# Processing Record 23 of Set 5 | kamaishi
# Processing Record 24 of Set 5 | muros
# Processing Record 25 of Set 5 | inuvik
# Processing Record 26 of Set 5 | asau
# Processing Record 27 of Set 5 | naze
# Processing Record 28 of Set 5 | kerema
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | gbarnga
# Processing Record 31 of Set 5 | svarstad
# Processing Record 32 of Set 5 | ndende
# Processing Record 33 of Set 5 | marsh harbour
# Processing Record 34 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 5 | tommot
# Processing Record 36 of Set 5 | aquin
# Processing Record 37 of Set 5 | ilulissat
# Processing Record 38 of Set 5 | vigrestad
# Processing Record 39 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 5 | kiama
# Processing Record 41 of Set 5 | lata
# Processing Record 42 of Set 5 | moshupa
# Processing Record 43 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 5 | kochevo
# Processing Record 45 of Set 5 | chivay
# Processing Record 46 of Set 5 | bintulu
# Processing Record 47 of Set 5 | huarmey
# Processing Record 48 of Set 5 | kasongo-lunda
# Processing Record 49 of Set 5 | moerai
# Processing Record 50 of Set 5 | issia
# Processing Record 1 of Set 6 | east wenatchee bench
# Processing Record 2 of Set 6 | petropavlovka
# Processing Record 3 of Set 6 | dongsheng
# Processing Record 4 of Set 6 | skjervoy
# Processing Record 5 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 6 | klyuchi
# Processing Record 7 of Set 6 | alice springs
# Processing Record 8 of Set 6 | pervomayskiy
# Processing Record 9 of Set 6 | we
# City not found. Skipping...
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | jha jha
# Processing Record 12 of Set 6 | lianyuan
# Processing Record 13 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 6 | saint-pacome
# City not found. Skipping...
# Processing Record 15 of Set 6 | innisfail
# Processing Record 16 of Set 6 | shahrud
# Processing Record 17 of Set 6 | daura
# Processing Record 18 of Set 6 | kalemie
# Processing Record 19 of Set 6 | gull lake
# Processing Record 20 of Set 6 | fortuna
# Processing Record 21 of Set 6 | abalak
# Processing Record 22 of Set 6 | iqaluit
# Processing Record 23 of Set 6 | sechura
# Processing Record 24 of Set 6 | mankono
# Processing Record 25 of Set 6 | yumen
# Processing Record 26 of Set 6 | port moresby
# Processing Record 27 of Set 6 | santo antonio do ica
# Processing Record 28 of Set 6 | takestan
# Processing Record 29 of Set 6 | thunder bay
# Processing Record 30 of Set 6 | krasne
# Processing Record 31 of Set 6 | mormugao
# Processing Record 32 of Set 6 | kozlovo
# Processing Record 33 of Set 6 | malakal
# Processing Record 34 of Set 6 | warmbad
# Processing Record 35 of Set 6 | bairiki
# Processing Record 36 of Set 6 | sabzevar
# Processing Record 37 of Set 6 | high rock
# Processing Record 38 of Set 6 | umm lajj
# Processing Record 39 of Set 6 | houma
# Processing Record 40 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 6 | voh
# Processing Record 42 of Set 6 | kabirwala
# Processing Record 43 of Set 6 | tomatlan
# Processing Record 44 of Set 6 | tateyama
# Processing Record 45 of Set 6 | changji
# Processing Record 46 of Set 6 | jhalu
# Processing Record 47 of Set 6 | oriximina
# Processing Record 48 of Set 6 | chengde
# Processing Record 49 of Set 6 | ampanihy
# Processing Record 50 of Set 6 | hambantota
# Processing Record 1 of Set 7 | mahebourg
# Processing Record 2 of Set 7 | kandrian
# Processing Record 3 of Set 7 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 4 of Set 7 | wapakoneta
# Processing Record 5 of Set 7 | maneadero
# Processing Record 6 of Set 7 | ambilobe
# Processing Record 7 of Set 7 | te anau
# Processing Record 8 of Set 7 | cangzhou
# Processing Record 9 of Set 7 | sao gabriel da cachoeira
# Processing Record 10 of Set 7 | teahupoo
# Processing Record 11 of Set 7 | dzhankoy
# Processing Record 12 of Set 7 | antofagasta
# Processing Record 13 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 14 of Set 7 | coihaique
# Processing Record 15 of Set 7 | yeppoon
# Processing Record 16 of Set 7 | naantali
# Processing Record 17 of Set 7 | boa vista
# Processing Record 18 of Set 7 | catamarca
# Processing Record 19 of Set 7 | itaituba
# Processing Record 20 of Set 7 | dunedin
# Processing Record 21 of Set 7 | ayagoz
# Processing Record 22 of Set 7 | samarai
# Processing Record 23 of Set 7 | anuradhapura
# Processing Record 24 of Set 7 | grand-santi
# Processing Record 25 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 26 of Set 7 | sept-iles
# Processing Record 27 of Set 7 | calama
# Processing Record 28 of Set 7 | vanderhoof
# Processing Record 29 of Set 7 | lodja
# Processing Record 30 of Set 7 | krasnoselkup
# Processing Record 31 of Set 7 | rantepao
# Processing Record 32 of Set 7 | goderich
# Processing Record 33 of Set 7 | ust-kuyga
# Processing Record 34 of Set 7 | lompoc
# Processing Record 35 of Set 7 | dudinka
# Processing Record 36 of Set 7 | linxia
# Processing Record 37 of Set 7 | malanje
# Processing Record 38 of Set 7 | baiyin
# Processing Record 39 of Set 7 | izhevskoye
# Processing Record 40 of Set 7 | mount isa
# Processing Record 41 of Set 7 | hualmay
# Processing Record 42 of Set 7 | waingapu
# Processing Record 43 of Set 7 | saint-joseph
# Processing Record 44 of Set 7 | sherbakul
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | sarkand
# Processing Record 47 of Set 7 | masuguru
# Processing Record 48 of Set 7 | guerrero negro
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | camana
# Processing Record 1 of Set 8 | kharp
# Processing Record 2 of Set 8 | shimoni
# Processing Record 3 of Set 8 | panambi
# Processing Record 4 of Set 8 | pionerskiy
# Processing Record 5 of Set 8 | grootfontein
# Processing Record 6 of Set 8 | airai
# Processing Record 7 of Set 8 | cocorit
# Processing Record 8 of Set 8 | kaniama
# Processing Record 9 of Set 8 | stromness
# Processing Record 10 of Set 8 | kapit
# Processing Record 11 of Set 8 | marsa matruh
# Processing Record 12 of Set 8 | rawson
# Processing Record 13 of Set 8 | rivadavia
# Processing Record 14 of Set 8 | tarrafal
# Processing Record 15 of Set 8 | san jose
# Processing Record 16 of Set 8 | mezen
# Processing Record 17 of Set 8 | saint george
# Processing Record 18 of Set 8 | saryshagan
# City not found. Skipping...
# Processing Record 19 of Set 8 | grants pass
# Processing Record 20 of Set 8 | saint-leu
# Processing Record 21 of Set 8 | alton
# Processing Record 22 of Set 8 | chapais
# Processing Record 23 of Set 8 | maceio
# Processing Record 24 of Set 8 | rincon
# Processing Record 25 of Set 8 | santa fe
# Processing Record 26 of Set 8 | aksarka
# Processing Record 27 of Set 8 | sao felix do xingu
# Processing Record 28 of Set 8 | henties bay
# Processing Record 29 of Set 8 | korostyshiv
# Processing Record 30 of Set 8 | khandbari
# Processing Record 31 of Set 8 | ambon
# Processing Record 32 of Set 8 | georgiyevskoye
# Processing Record 33 of Set 8 | pescia
# Processing Record 34 of Set 8 | sao joao da barra
# Processing Record 35 of Set 8 | parrita
# Processing Record 36 of Set 8 | carballo
# Processing Record 37 of Set 8 | bulgan
# Processing Record 38 of Set 8 | puerto carreno
# Processing Record 39 of Set 8 | kitui
# Processing Record 40 of Set 8 | beringovskiy
# Processing Record 41 of Set 8 | batemans bay
# Processing Record 42 of Set 8 | opuwo
# Processing Record 43 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 44 of Set 8 | antsohihy
# Processing Record 45 of Set 8 | strezhevoy
# Processing Record 46 of Set 8 | listvyagi
# Processing Record 47 of Set 8 | kaitangata
# Processing Record 48 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 49 of Set 8 | sychevka
# Processing Record 50 of Set 8 | prince rupert
# Processing Record 1 of Set 9 | nanhai
# Processing Record 2 of Set 9 | kulachi
# Processing Record 3 of Set 9 | emporia
# Processing Record 4 of Set 9 | bolobo
# Processing Record 5 of Set 9 | manta
# Processing Record 6 of Set 9 | ostrovnoy
# Processing Record 7 of Set 9 | severo-kurilsk
# Processing Record 8 of Set 9 | vila franca do campo
# Processing Record 9 of Set 9 | erzin
# Processing Record 10 of Set 9 | gallup
# Processing Record 11 of Set 9 | dubti
# Processing Record 12 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 13 of Set 9 | nabire
# Processing Record 14 of Set 9 | matamoros
# Processing Record 15 of Set 9 | bolshoye nagatkino
# Processing Record 16 of Set 9 | vila velha
# Processing Record 17 of Set 9 | dali
# Processing Record 18 of Set 9 | guicheng
# City not found. Skipping...
# Processing Record 19 of Set 9 | tecoanapa
# Processing Record 20 of Set 9 | hoopstad
# Processing Record 21 of Set 9 | mildura
# Processing Record 22 of Set 9 | geraldton
# Processing Record 23 of Set 9 | haapiti
# Processing Record 24 of Set 9 | ughelli
# Processing Record 25 of Set 9 | comodoro rivadavia
# Processing Record 26 of Set 9 | batasan
# Processing Record 27 of Set 9 | trapani
# Processing Record 28 of Set 9 | viedma
# Processing Record 29 of Set 9 | concordia
# Processing Record 30 of Set 9 | aksu
# Processing Record 31 of Set 9 | zhuhai
# Processing Record 32 of Set 9 | ninghai
# Processing Record 33 of Set 9 | igunga
# Processing Record 34 of Set 9 | ingham
# Processing Record 35 of Set 9 | scottsbluff
# Processing Record 36 of Set 9 | olafsvik
# Processing Record 37 of Set 9 | kutum
# Processing Record 38 of Set 9 | bethanien
# Processing Record 39 of Set 9 | coquimbo
# Processing Record 40 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 41 of Set 9 | bandarbeyla
# Processing Record 42 of Set 9 | ivanivka
# Processing Record 43 of Set 9 | jadu
# Processing Record 44 of Set 9 | mehran
# Processing Record 45 of Set 9 | corning
# Processing Record 46 of Set 9 | marshall
# Processing Record 47 of Set 9 | beloha
# Processing Record 48 of Set 9 | torbay
# Processing Record 49 of Set 9 | atasu
# Processing Record 50 of Set 9 | kieta
# Processing Record 1 of Set 10 | bernardino de campos
# Processing Record 2 of Set 10 | bialystok
# Processing Record 3 of Set 10 | dunhua
# Processing Record 4 of Set 10 | dubbo
# Processing Record 5 of Set 10 | vanavara
# Processing Record 6 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 7 of Set 10 | gornopravdinsk
# Processing Record 8 of Set 10 | tambacounda
# Processing Record 9 of Set 10 | janauba
# Processing Record 10 of Set 10 | noshiro
# Processing Record 11 of Set 10 | msanga
# Processing Record 12 of Set 10 | tulun
# Processing Record 13 of Set 10 | ust-nera
# Processing Record 14 of Set 10 | carmen
# Processing Record 15 of Set 10 | umm kaddadah
# Processing Record 16 of Set 10 | dong hoi
# Processing Record 17 of Set 10 | tondela
# Processing Record 18 of Set 10 | havelock
# Processing Record 19 of Set 10 | namibe
# Processing Record 20 of Set 10 | solwezi
# Processing Record 21 of Set 10 | cozumel
# Processing Record 22 of Set 10 | arsk
# Processing Record 23 of Set 10 | novaya ladoga
# Processing Record 24 of Set 10 | hofn
# Processing Record 25 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 10 | nara
# Processing Record 27 of Set 10 | rockport
# Processing Record 28 of Set 10 | douentza
# Processing Record 29 of Set 10 | katsuura
# Processing Record 30 of Set 10 | tabou
# Processing Record 31 of Set 10 | tura
# Processing Record 32 of Set 10 | nizwa
# Processing Record 33 of Set 10 | bato
# Processing Record 34 of Set 10 | port-cartier
# Processing Record 35 of Set 10 | vung tau
# Processing Record 36 of Set 10 | aklavik
# Processing Record 37 of Set 10 | necochea
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 10 | the valley
# Processing Record 41 of Set 10 | san patricio
# Processing Record 42 of Set 10 | manzhouli
# Processing Record 43 of Set 10 | leningradskiy
# Processing Record 44 of Set 10 | jibuti
# Processing Record 45 of Set 10 | juneau
# Processing Record 46 of Set 10 | traralgon
# Processing Record 47 of Set 10 | lasem
# Processing Record 48 of Set 10 | shingu
# Processing Record 49 of Set 10 | soe
# Processing Record 50 of Set 10 | gemena
# Processing Record 1 of Set 11 | gambela
# Processing Record 2 of Set 11 | santa cruz
# Processing Record 3 of Set 11 | effium
# Processing Record 4 of Set 11 | hay river
# Processing Record 5 of Set 11 | banikoara
# Processing Record 6 of Set 11 | bam
# Processing Record 7 of Set 11 | mastung
# Processing Record 8 of Set 11 | ialibu
# Processing Record 9 of Set 11 | arcos
# Processing Record 10 of Set 11 | dicabisagan
# Processing Record 11 of Set 11 | farmington
# Processing Record 12 of Set 11 | luanda
# Processing Record 13 of Set 11 | mattawa
# Processing Record 14 of Set 11 | bejar
# Processing Record 15 of Set 11 | lerwick
# Processing Record 16 of Set 11 | benguela
# Processing Record 17 of Set 11 | oranjestad
# Processing Record 18 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 19 of Set 11 | cordoba
# Processing Record 20 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 21 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 22 of Set 11 | bud
# Processing Record 23 of Set 11 | gannan
# Processing Record 24 of Set 11 | tevaitoa
# Processing Record 25 of Set 11 | pangnirtung
# Processing Record 26 of Set 11 | fereydun kenar
# Processing Record 27 of Set 11 | hurghada
# Processing Record 28 of Set 11 | manuk mangkaw
# Processing Record 29 of Set 11 | muriwai beach
# Processing Record 30 of Set 11 | maragogi
# Processing Record 31 of Set 11 | aztec
# Processing Record 32 of Set 11 | lorengau
# Processing Record 33 of Set 11 | derzhavinsk
# Processing Record 34 of Set 11 | saskylakh
# Processing Record 35 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 11 | portoferraio
# Processing Record 37 of Set 11 | chilca
# Processing Record 38 of Set 11 | fairbanks
# Processing Record 39 of Set 11 | baoning
# Processing Record 40 of Set 11 | atikokan
# Processing Record 41 of Set 11 | iwanai
# Processing Record 42 of Set 11 | flinders
# Processing Record 43 of Set 11 | shirokiy
# Processing Record 44 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 45 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 46 of Set 11 | mandalgovi
# Processing Record 47 of Set 11 | tombouctou
# Processing Record 48 of Set 11 | banda aceh
# Processing Record 49 of Set 11 | sampit
# Processing Record 50 of Set 11 | port-gentil
# Processing Record 1 of Set 12 | quatre cocos
# Processing Record 2 of Set 12 | egvekinot
# Processing Record 3 of Set 12 | sabya
# Processing Record 4 of Set 12 | muisne
# Processing Record 5 of Set 12 | port hardy
# Processing Record 6 of Set 12 | slave lake
# Processing Record 7 of Set 12 | alofi
# Processing Record 8 of Set 12 | sorland
# Processing Record 9 of Set 12 | la ronge
# Processing Record 10 of Set 12 | grand-lahou
# Processing Record 11 of Set 12 | kiruna
# Processing Record 12 of Set 12 | socorro
# Processing Record 13 of Set 12 | parys
# Processing Record 14 of Set 12 | montemor-o-novo
# Processing Record 15 of Set 12 | kinsale
# Processing Record 16 of Set 12 | albury
# Processing Record 17 of Set 12 | coari
# Processing Record 18 of Set 12 | tuy hoa
# Processing Record 19 of Set 12 | altay
# Processing Record 20 of Set 12 | kushima
# Processing Record 21 of Set 12 | caravelas
# Processing Record 22 of Set 12 | ibotirama
# Processing Record 23 of Set 12 | joensuu
# Processing Record 24 of Set 12 | vanimo
# Processing Record 25 of Set 12 | rockhampton
# Processing Record 26 of Set 12 | matagami
# Processing Record 27 of Set 12 | asosa
# Processing Record 28 of Set 12 | saltillo
# Processing Record 29 of Set 12 | oregon city
# Processing Record 30 of Set 12 | isangel
# Processing Record 31 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 12 | nome
# Processing Record 33 of Set 12 | bumbuna
# Processing Record 34 of Set 12 | teknaf
# Processing Record 35 of Set 12 | mizan teferi
# Processing Record 36 of Set 12 | prescott
# Processing Record 37 of Set 12 | timon
# Processing Record 38 of Set 12 | forest hills
# Processing Record 39 of Set 12 | belovo
# Processing Record 40 of Set 12 | dingzhou
# Processing Record 41 of Set 12 | bajo baudo
# City not found. Skipping...
# Processing Record 42 of Set 12 | bomi
# Processing Record 43 of Set 12 | puri
# Processing Record 44 of Set 12 | wuzhou
# Processing Record 45 of Set 12 | san quintin
# Processing Record 46 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 47 of Set 12 | virginia beach
# Processing Record 48 of Set 12 | arona
# Processing Record 49 of Set 12 | daru
# Processing Record 50 of Set 12 | tual
# Processing Record 1 of Set 13 | sangar
# Processing Record 2 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 13 | azul
# Processing Record 4 of Set 13 | waipawa
# Processing Record 5 of Set 13 | beberibe
# Processing Record 6 of Set 13 | ust-maya
# Processing Record 7 of Set 13 | honningsvag
# Processing Record 8 of Set 13 | clemencia
# Processing Record 9 of Set 13 | karakendzha
# City not found. Skipping...
# Processing Record 10 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 11 of Set 13 | namatanai
# Processing Record 12 of Set 13 | griffith
# Processing Record 13 of Set 13 | erenhot
# Processing Record 14 of Set 13 | semporna
# Processing Record 15 of Set 13 | dinghai
# Processing Record 16 of Set 13 | shelburne
# Processing Record 17 of Set 13 | santa magdalena
# Processing Record 18 of Set 13 | jiuquan
# Processing Record 19 of Set 13 | filingue
# Processing Record 20 of Set 13 | ulladulla
# Processing Record 21 of Set 13 | carutapera
# Processing Record 22 of Set 13 | benxi
# Processing Record 23 of Set 13 | kamenka
# Processing Record 24 of Set 13 | danilovka
# Processing Record 25 of Set 13 | salinopolis
# Processing Record 26 of Set 13 | geelong
# Processing Record 27 of Set 13 | belmonte
# Processing Record 28 of Set 13 | vao
# Processing Record 29 of Set 13 | saint-pierre
# Processing Record 30 of Set 13 | shiyan
# Processing Record 31 of Set 13 | rosita
# Processing Record 32 of Set 13 | prieska
# Processing Record 33 of Set 13 | wangaratta
# Processing Record 34 of Set 13 | rocha
# Processing Record 35 of Set 13 | sivaki
# Processing Record 36 of Set 13 | ponta delgada
# Processing Record 37 of Set 13 | alamogordo
# Processing Record 38 of Set 13 | kuusamo
# Processing Record 39 of Set 13 | rypefjord
# Processing Record 40 of Set 13 | anton lizardo
# Processing Record 41 of Set 13 | naklo nad notecia
# Processing Record 42 of Set 13 | high level
# Processing Record 43 of Set 13 | mimoso do sul
# Processing Record 44 of Set 13 | caraguatatuba
# Processing Record 45 of Set 13 | san policarpo
# Processing Record 46 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 47 of Set 13 | wasilla
# Processing Record 48 of Set 13 | novomykolayivka
# Processing Record 49 of Set 13 | eyl
# Processing Record 50 of Set 13 | glenluce
# Processing Record 1 of Set 14 | north bend
# Processing Record 2 of Set 14 | awjilah
# Processing Record 3 of Set 14 | uchaly
# Processing Record 4 of Set 14 | pizarro
# Processing Record 5 of Set 14 | grants
# Processing Record 6 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 14 | san cristobal
# Processing Record 8 of Set 14 | bokajan
# Processing Record 9 of Set 14 | vynohradove
# Processing Record 10 of Set 14 | nambucca heads
# Processing Record 11 of Set 14 | runkel
# Processing Record 12 of Set 14 | kyren
# Processing Record 13 of Set 14 | birjand
# Processing Record 14 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 14 | nagorsk
# Processing Record 16 of Set 14 | zavodoukovsk
# Processing Record 17 of Set 14 | wageningen
# Processing Record 18 of Set 14 | cardston
# Processing Record 19 of Set 14 | palmerston
# Processing Record 20 of Set 14 | roald
# Processing Record 21 of Set 14 | shimoda
# Processing Record 22 of Set 14 | manitouwadge
# Processing Record 23 of Set 14 | kytmanovo
# Processing Record 24 of Set 14 | xining
# Processing Record 25 of Set 14 | arlit
# Processing Record 26 of Set 14 | valparaiso
# Processing Record 27 of Set 14 | harrisonburg
# Processing Record 28 of Set 14 | ormara
# Processing Record 29 of Set 14 | bosaso
# Processing Record 30 of Set 14 | butembo
# Processing Record 31 of Set 14 | gravdal
# Processing Record 32 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 33 of Set 14 | qeshm
# Processing Record 34 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 35 of Set 14 | isiolo
# Processing Record 36 of Set 14 | berezovyy
# Processing Record 37 of Set 14 | senges
# Processing Record 38 of Set 14 | maromitsa
# Processing Record 39 of Set 14 | sagarejo
# Processing Record 40 of Set 14 | le vauclin
# Processing Record 41 of Set 14 | panjakent
# Processing Record 42 of Set 14 | gizo
# Processing Record 43 of Set 14 | mama
# Processing Record 44 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 45 of Set 14 | hun
# Processing Record 46 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 14 | reserva
# Processing Record 48 of Set 14 | evensk
# Processing Record 49 of Set 14 | knysna
# Processing Record 50 of Set 14 | monte alegre de sergipe
# Processing Record 1 of Set 15 | galveston
# Processing Record 2 of Set 15 | diosti
# Processing Record 3 of Set 15 | panaba
# Processing Record 4 of Set 15 | matara
# Processing Record 5 of Set 15 | alexandria
# Processing Record 6 of Set 15 | totness
# Processing Record 7 of Set 15 | deshnok
# Processing Record 8 of Set 15 | xingcheng
# Processing Record 9 of Set 15 | novosil
# Processing Record 10 of Set 15 | launceston
# Processing Record 11 of Set 15 | kupang
# Processing Record 12 of Set 15 | puerto lempira
# Processing Record 13 of Set 15 | great yarmouth
# Processing Record 14 of Set 15 | orotukan
# Processing Record 15 of Set 15 | yulara
# Processing Record 16 of Set 15 | ginir
# Processing Record 17 of Set 15 | port blair
# Processing Record 18 of Set 15 | capelinha
# Processing Record 19 of Set 15 | irece
# Processing Record 20 of Set 15 | tignere
# Processing Record 21 of Set 15 | palu
# Processing Record 22 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 15 | udachnyy
# Processing Record 24 of Set 15 | swan hill
# Processing Record 25 of Set 15 | krasnousolskiy
# City not found. Skipping...
# Processing Record 26 of Set 15 | mehamn
# Processing Record 27 of Set 15 | porto novo
# Processing Record 28 of Set 15 | lewistown
# Processing Record 29 of Set 15 | bizhbulyak
# Processing Record 30 of Set 15 | chokwe
# Processing Record 31 of Set 15 | kenai
# Processing Record 32 of Set 15 | parakou
# Processing Record 33 of Set 15 | punta alta
# Processing Record 34 of Set 15 | muromtsevo
# Processing Record 35 of Set 15 | havre-saint-pierre
# Processing Record 36 of Set 15 | bijar
# Processing Record 37 of Set 15 | villazon
# Processing Record 38 of Set 15 | fray bentos
# Processing Record 39 of Set 15 | casa nova
# Processing Record 40 of Set 15 | uvarovo
# Processing Record 41 of Set 15 | araouane
# Processing Record 42 of Set 15 | mayo
# Processing Record 43 of Set 15 | pocone
# Processing Record 44 of Set 15 | mitsamiouli
# Processing Record 45 of Set 15 | poronaysk
# Processing Record 46 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 47 of Set 15 | acapulco
# Processing Record 48 of Set 15 | waverley
# Processing Record 49 of Set 15 | indiaroba
# Processing Record 50 of Set 15 | mastic beach
# Processing Record 1 of Set 16 | bahia de caraquez
# Processing Record 2 of Set 16 | balaipungut
# Processing Record 3 of Set 16 | hasaki
# Processing Record 4 of Set 16 | lipari
# Processing Record 5 of Set 16 | havoysund
# Processing Record 6 of Set 16 | pampierstad
# Processing Record 7 of Set 16 | lujan
# Processing Record 8 of Set 16 | ovalle
# Processing Record 9 of Set 16 | ville-marie
# Processing Record 10 of Set 16 | pozo colorado
# Processing Record 11 of Set 16 | kharhial
# Processing Record 12 of Set 16 | ertil
# Processing Record 13 of Set 16 | wufeng
# Processing Record 14 of Set 16 | jalu
# Processing Record 15 of Set 16 | pemba
# Processing Record 16 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 16 | alta floresta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0          Jian  27.1172  114.9793     65.57       broken clouds        71
# 1        Salima -13.7804   34.4587     90.37           clear sky        19
# 2        Dikson  73.5069   80.5464     31.33     overcast clouds        70
# 3  Punta Arenas -53.1500  -70.9167     46.51       broken clouds        61
# 4         Jizan  17.3333   42.6667     92.34    scattered clouds        49
# 5  Longyearbyen  78.2186   15.6401     39.04          few clouds        75
# 6        Pandan  14.0453  124.1694     80.15     overcast clouds        87
# 7     Riberalta -10.9833  -66.1000     86.20    scattered clouds        70
# 8   Tuktoyaktuk  69.4541 -133.0374     28.40                 fog       100
# 9        Safaga  26.7292   33.9365     87.40           clear sky        53
#
#    Cloudiness  Wind Speed Country
# 0          58        8.75      CN
# 1           2        3.36      MW
# 2         100        5.01      RU
# 3          75       11.50      CL
# 4          43       12.08      SA
# 5          20       17.27      SJ
# 6          96        7.74      PH
# 7          43        4.61      BO
# 8         100       12.66      CA
# 9           8       10.18      EG

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0          Jian  27.1172  114.9793     65.57       broken clouds        71
# 1        Salima -13.7804   34.4587     90.37           clear sky        19
# 2        Dikson  73.5069   80.5464     31.33     overcast clouds        70
# 3  Punta Arenas -53.1500  -70.9167     46.51       broken clouds        61
# 4         Jizan  17.3333   42.6667     92.34    scattered clouds        49
# 5  Longyearbyen  78.2186   15.6401     39.04          few clouds        75
# 6        Pandan  14.0453  124.1694     80.15     overcast clouds        87
# 7     Riberalta -10.9833  -66.1000     86.20    scattered clouds        70
# 8   Tuktoyaktuk  69.4541 -133.0374     28.40                 fog       100
# 9        Safaga  26.7292   33.9365     87.40           clear sky        53
#
#    Cloudiness  Wind Speed Country
# 0          58        8.75      CN
# 1           2        3.36      MW
# 2         100        5.01      RU
# 3          75       11.50      CL
# 4          43       12.08      SA
# 5          20       17.27      SJ
# 6          96        7.74      PH
# 7          43        4.61      BO
# 8         100       12.66      CA
# 9           8       10.18      EG

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df =city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Jian      CN  27.1172  114.9793     65.57        71          58
# 1           Salima      MW -13.7804   34.4587     90.37        19           2
# 2           Dikson      RU  73.5069   80.5464     31.33        70         100
# 3     Punta Arenas      CL -53.1500  -70.9167     46.51        61          75
# 4            Jizan      SA  17.3333   42.6667     92.34        49          43
# ..             ...     ...      ...       ...       ...       ...         ...
# 703          Ertil      RU  51.8406   40.8056     49.33        80         100
# 704         Wufeng      CN  27.4500  104.8333     54.68        95          89
# 705           Jalu      LY  29.0331   21.5482     87.03        29           0
# 706          Pemba      MZ -12.9740   40.5178     81.30        65          20
# 707  Alta Floresta      BR  -9.8756  -56.0861     89.42        55          81
#
#      Wind Speed Current Description
# 0          8.75       broken clouds
# 1          3.36           clear sky
# 2          5.01     overcast clouds
# 3         11.50       broken clouds
# 4         12.08    scattered clouds
# ..          ...                 ...
# 703       10.11     overcast clouds
# 704        3.85     overcast clouds
# 705       10.13           clear sky
# 706       10.36          few clouds
# 707        4.61       broken clouds
#
# [708 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
csv_weather_file = "Weatherpy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
